# %% [markdown]
# # Anameka South - ACCESS CM2
#
# Notebook for processing ACCESS CM2 climate model data.

# %% [markdown]
# ## Setup and Imports

# %%
import pandas as pd
import numpy as np
import json
import os
from pathlib import Path

print("Libraries imported successfully")
